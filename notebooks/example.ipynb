# %%
# %matplotlib notebook
import logging
logging.basicConfig(level=logging.INFO)

# %%
# !pip install sentinelloader
# Out:
# Requirement already satisfied: sentinelloader in /usr/local/lib/python3.6/dist-packages/sentinelloader-1.1.1-py3.6.egg (1.1.1)
# Requirement already satisfied: uuid>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (1.30)
# Requirement already satisfied: gdal>=2.2.2 in /usr/lib/python3/dist-packages (from sentinelloader) (3.0.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (2.22.0)
# Requirement already satisfied: pandas>=0.24.1 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (0.25.3)
# Requirement already satisfied: geopandas>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (0.6.2)
# Requirement already satisfied: shapely>=1.6.4 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (1.6.4.post2)
# Requirement already satisfied: sentinelsat>=0.12.2 in /usr/local/lib/python3.6/dist-packages (from sentinelloader) (0.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->sentinelloader) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->sentinelloader) (1.25.7)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.21.0->sentinelloader) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.21.0->sentinelloader) (3.0.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.1->sentinelloader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.1->sentinelloader) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.1->sentinelloader) (2.8.1)
# Requirement already satisfied: fiona in /usr/local/lib/python3.6/dist-packages (from geopandas>=0.4.1->sentinelloader) (1.8.13)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.6/dist-packages (from geopandas>=0.4.1->sentinelloader) (2.4.2.post1)
# Requirement already satisfied: geomet in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (0.2.1.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (1.13.0)
# Requirement already satisfied: geojson>=2 in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (2.5.0)
# Requirement already satisfied: html2text in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (2020.1.16)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from sentinelsat>=0.12.2->sentinelloader) (4.41.1)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader) (1.1.1)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader) (19.3.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader) (0.5.0)
# WARNING: You are using pip version 19.3.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sentinelloader import Sentinel2Loader

# %%
# !pip uninstall -y sentinelloader

# used to test release
# !pip install git+https://github.com/flaviostutz/sentinelloader
from sentinelloader import Sentinel2Loader

# used during local development
# from sentinelloader.sentinel2loader import Sentinel2Loader
# Out:
# Uninstalling sentinelloader-1.1.1:
#   Successfully uninstalled sentinelloader-1.1.1
# Collecting git+https://github.com/flaviostutz/sentinelloader
#   Cloning https://github.com/flaviostutz/sentinelloader to /tmp/pip-req-build-14poc0nk
# Requirement already satisfied: uuid>=1.3.0 in /usr/local/lib/python3.5/dist-packages/uuid-1.30-py3.5.egg (from sentinelloader==1.1.1) (1.30)
# Requirement already satisfied: gdal>=2.2.2 in /usr/lib/python3/dist-packages (from sentinelloader==1.1.1) (2.2.2)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.5/dist-packages (from sentinelloader==1.1.1) (2.21.0)
# Requirement already satisfied: pandas>=0.24.1 in /usr/local/lib/python3.5/dist-packages (from sentinelloader==1.1.1) (0.24.2)
# Requirement already satisfied: geopandas>=0.4.1 in /usr/local/lib/python3.5/dist-packages (from sentinelloader==1.1.1) (0.4.1)
# Requirement already satisfied: shapely>=1.6.4 in /usr/local/lib/python3.5/dist-packages (from sentinelloader==1.1.1) (1.6.4.post2)
# Requirement already satisfied: sentinelsat>=0.12.2 in /usr/local/lib/python3.5/dist-packages/sentinelsat-1.1.0-py3.5.egg (from sentinelloader==1.1.1) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.5/dist-packages (from requests>=2.21.0->sentinelloader==1.1.1) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.5/dist-packages (from requests>=2.21.0->sentinelloader==1.1.1) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.5/dist-packages (from requests>=2.21.0->sentinelloader==1.1.1) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.5/dist-packages (from requests>=2.21.0->sentinelloader==1.1.1) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.5/dist-packages (from pandas>=0.24.1->sentinelloader==1.1.1) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.5/dist-packages (from pandas>=0.24.1->sentinelloader==1.1.1) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.5/dist-packages (from pandas>=0.24.1->sentinelloader==1.1.1) (1.16.2)
# Requirement already satisfied: fiona in /usr/local/lib/python3.5/dist-packages (from geopandas>=0.4.1->sentinelloader==1.1.1) (1.8.6)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.5/dist-packages (from geopandas>=0.4.1->sentinelloader==1.1.1) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.5/dist-packages (from sentinelsat>=0.12.2->sentinelloader==1.1.1) (7.0)
# Requirement already satisfied: geojson>=2 in /usr/local/lib/python3.5/dist-packages/geojson-2.5.0-py3.5.egg (from sentinelsat>=0.12.2->sentinelloader==1.1.1) (2.5.0)
# Requirement already satisfied: geomet in /usr/local/lib/python3.5/dist-packages/geomet-0.3.0-py3.5.egg (from sentinelsat>=0.12.2->sentinelloader==1.1.1) (0.3.0)
# Requirement already satisfied: html2text in /usr/local/lib/python3.5/dist-packages/html2text-2020.1.16-py3.5.egg (from sentinelsat>=0.12.2->sentinelloader==1.1.1) (2020.1.16)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.5/dist-packages (from sentinelsat>=0.12.2->sentinelloader==1.1.1) (4.31.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.5/dist-packages (from python-dateutil>=2.5.0->pandas>=0.24.1->sentinelloader==1.1.1) (1.12.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.5/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader==1.1.1) (2.3.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.5/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader==1.1.1) (19.1.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.5/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader==1.1.1) (0.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.5/dist-packages (from fiona->geopandas>=0.4.1->sentinelloader==1.1.1) (1.1.1)
# Building wheels for collected packages: sentinelloader
#   Building wheel for sentinelloader (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0_ovytpj/wheels/50/ec/84/a8c56ef0693bfee8662a78cc6ec6695b8dbffca99284c56e5f
# Successfully built sentinelloader
# Installing collected packages: sentinelloader
# Successfully installed sentinelloader-1.1.1
# You are using pip version 19.0.3, however version 20.3.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-8-5a7d51863c62>", line 5, in <module>
#     from sentinelloader import Sentinel2Loader
#
#   File "/notebooks/sentinelloader/__init__.py", line 1, in <module>
#     from .sentinel2loader import Sentinel2Loader
#
#   File "/notebooks/sentinelloader/sentinel2loader.py", line 1, in <module>
#     from sentinelsat import SentinelAPI
#
#   File "/usr/local/lib/python3.5/dist-packages/sentinelsat-1.1.0-py3.5.egg/sentinelsat/__init__.py", line 4, in <module>
#     from . import sentinel
#
#   File "/usr/local/lib/python3.5/dist-packages/sentinelsat-1.1.0-py3.5.egg/sentinelsat/sentinel.py", line 287
#     self.logger.info(f"Found {count:,} products")
#                                                ^
# SyntaxError: invalid syntax

# %%
from time import time
logger = logging.getLogger('sentinelloader')

class Timer:
    def __init__(self, name, debug=True):
        self._name = name
        self._debug = debug
        self.start()
        self._lastElapsed = None
    
    def start(self):
        self._start = time()
        if(self._debug):
            logger.info('> [started] ' + self._name + '...')

    def stop(self):
        self._lastElapsed = (time()-self._start)
        if(self._debug):
            logger.info('> [done]    {} ({:.3f} ms)'.format(self._name, self._lastElapsed*1000))
            
    def elapsed(self):
        if(self._lastElapsed != None):
            return (self._lastElapsed)
        else:
            return (time()-self._start)

# %%
import matplotlib.patches as mpatches
from osgeo import gdal, osr
import cartopy.crs as ccrs
import numpy as np

def showGeoTiffs(geoTiffFiles, geometries=None, labels=None, cols=4, size=6, cmap=None, cmap_min=None, cmap_max=None, interpolation=None, legendHandles=None, group_by_label=False, name='image', output_dir=None, transformData=None):
    """geometries - list of geoseries from GeoPandas
       labels - list os strings
       getTiffFiles - list of tiff file paths
    """
    logger.info('showing ' + str(len(geoTiffFiles)) + ' images')
    fig = plt.figure()
    rows = int(len(geoTiffFiles)/cols)+1
    t = Timer('generating image patches. rows=' + str(rows) + '; cols=' + str(cols))
    fig.set_size_inches(cols*size, rows*size)

    image_indexes = range(len(geoTiffFiles))

    #order indexes by label
    if(group_by_label==True and image_labels!=None):
        index_label_map = []
        for i,label in enumerate(image_labels):
            index_label_map.append((i,label))
        label_image_map = np.array(index_label_map, dtype=[('index',int),('label',int)])
        label_image_map = np.sort(label_image_map, order='label')
        image_indexes = []
        for a in label_image_map:
            image_indexes.append(a[0])

    c = 0
    for i in image_indexes:
        ds = gdal.Open(geoTiffFiles[i])
        data = ds.ReadAsArray()
        gt = ds.GetGeoTransform()
        proj = ds.GetProjection()

        inproj = osr.SpatialReference()
        inproj.ImportFromWkt(proj)

        projcs = inproj.GetAuthorityCode('PROJCS')
        projection = ccrs.epsg(projcs)

        ax = fig.add_subplot(rows,cols,c+1, projection=projection)

        extent = (gt[0], gt[0] + ds.RasterXSize * gt[1],
                  gt[3] + ds.RasterYSize * gt[5], gt[3])

        
        #seems like this data has multiple channels and the channels area indexed from the first position. invert it
        if data.shape[0]<5:
            data = data[:3, :, :].transpose((1, 2, 0))
        else:
            if transformData!=None:
                data = transformData(data)

        if data.dtype in [np.uint8, np.uint16, np.uint32]:
            if cmap_min==None:
                cmap_min = np.iinfo(data.dtype).min
            if cmap_max==None:
                cmap_max = np.iinfo(data.dtype).max
#         if(cmap==None):
#             data = data.astype('uint8')
                
        ax.imshow(data, alpha=1.0, transform=projection, extent=extent, cmap=cmap, vmin=cmap_min, vmax=cmap_max, interpolation=interpolation, origin='upper')
        if legendHandles!=None:
            ax.legend(handles=legendHandles, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

        if(geometries!=None):
            df_epsg = geometries[i].to_crs(epsg=ax.projection.epsg_code)
            df_epsg.plot(ax=ax, facecolor='none', edgecolor='black', linestyle='--', linewidth=2)
        
        if(labels!=None):
            ax.text(0.5, 0, str(labels[i]), horizontalalignment='center', verticalalignment='bottom', transform=ax.transAxes, fontsize=14, style='normal', color='red')

        c = c + 1
    
    if(output_dir!=None):
        f = output_dir + name + '.jpg'
        plt.savefig(f)
        plt.close(fig)
    else:
        plt.show()
        
    t.stop()

def sclColors():
    colors = ['black','red','dimgray','brown','green','yellow','blue','dimgray','darkgray','lightgray','skyblue','magenta']
    return colors

def sclLegendPatches():
    colors = sclColors()
    labels = ['no data','defective','dark area','cloud shadows','vegetation','not vegetated','water','unclassified','cloud medium prob','cloud high prob','thin cirrus','snow']
    patches = [ mpatches.Patch(color=colors[i], label=labels[i]) for i in range(11) ]
    return patches

# %%
# %matplotlib inline
import logging
import os
from osgeo import gdal
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
import math
import geopandas as gpd
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature
from cartopy.io.shapereader import Reader
from descartes import PolygonPatch
import fiona
from pprint import pprint
import re

logging.basicConfig(level=logging.INFO)

sl = Sentinel2Loader('/notebooks/data/output/sentinelcache', 
                    os.environ['COPERNICUS_USER'], os.environ['COPERNICUS_PASSWORD'],
                    apiUrl='https://scihub.copernicus.eu/apihub/', showProgressbars=True, cloudCoverage=(0,100))



df = gpd.read_file("/notebooks/test/sample2.shp")
df.crs = {'init' :'epsg:4326'}

coords = df['geometry'][0]




d1 = '2019-12-22'
d2 = '2020-02-27'
# d1 = '2019-01-11'
# d2 = '2019-02-06'

print(coords)
print("getRegionHistory 1")
geoTiffs = sl.getRegionHistory(coords, 'TCI', '60m', d1, d2, daysStep=5)

geometries = []
labels = []
for geoTiff in geoTiffs:
    geometries.append(df)
    d = re.search('[0-9]{4}-[0-9]{2}-[0-9]{2}', geoTiff)
    labels.append(d.group(0))

showGeoTiffs(geoTiffs, geometries=geometries, labels=labels, cols=10, size=4,)

for geoTiff in geoTiffs:
    os.remove(geoTiff)

  




print("getRegionHistory 2")
geoTiffs = sl.getRegionHistory(coords, 'SCL', '60m', d1, d2, daysStep=5)

geometries = []
labels = []
for geoTiff in geoTiffs:
    geometries.append(df)
    d = re.search('[0-9]{4}-[0-9]{2}-[0-9]{2}', geoTiff)
    labels.append(d.group(0))

showGeoTiffs(geoTiffs, geometries=geometries, labels=labels, cols=10, size=4, cmap=mpl.colors.ListedColormap(sclColors()), cmap_min=0, cmap_max=11, legendHandles=sclLegendPatches())

for geoTiff in geoTiffs:
    os.remove(geoTiff)


    
    
    
    
    
geoTiffs = sl.getRegionHistory(coords, 'NDVI', '60m', d1, d2, daysStep=5)

geometries = []
labels = []
for geoTiff in geoTiffs:
    geometries.append(df)
    d = re.search('[0-9]{4}-[0-9]{2}-[0-9]{2}', geoTiff)
    labels.append(d.group(0))

def td(data):
    return np.negative(data)
 
showGeoTiffs(geoTiffs, geometries=geometries, labels=labels, cols=10, size=4, transformData=td, cmap='viridis', interpolation='none')

for geoTiff in geoTiffs:
    os.remove(geoTiff)
    

    





# geoTiffs = sl.getRegionHistory(coords, 'NDVI', '60m', '2018-06-11', '2019-03-11', daysStep=5)

# geometries = []
# labels = []
# for geoTiff in geoTiffs:
#     geometries.append(df)
#     d = re.search('[0-9]{4}-[0-9]{2}-[0-9]{2}', geoTiff)
#     labels.append(d.group(0))

# def td(data):
# #     v[v>200] = 255
#     print(np.mean(data))
#     return data
 
# showGeoTiffs(geoTiffs, geometries=geometries, labels=labels, transformData=td, cmap='viridis', cmap_min=-1, cmap_max=1)

# for geoTiff in geoTiffs:
#     os.remove(geoTiff)

    
    
    
plt.show()
# Out:
# INFO:sentinelloader:Getting region history for band TCI from 2019-12-22 to 2020-02-27 at 60m
# POLYGON Z ((-55.7005254871978 -13.3255356572483 0, -55.6991419460571 -13.3476412354778 0, -55.6994626679625 -13.3482968267724 0, -55.6993622255233 -13.3497238029627 0, -55.6990879718946 -13.3512050194787 0, -55.6987785623234 -13.3516544880401 0, -55.7009726154231 -13.3521465384388 0, -55.7031391574231 -13.3478350497349 0, -55.70365985481779 -13.3477166261783 0, -55.7042048225458 -13.3481784524516 0, -55.7053983895748 -13.3485070297582 0, -55.7071743431305 -13.350239177507 0, -55.7073679164227 -13.3508664639014 0, -55.707297910641 -13.3536846078021 0, -55.70845582938671 -13.3547391417037 0, -55.7083650623632 -13.3558936045135 0, -55.70920687339019 -13.3573796093408 0, -55.7107993017724 -13.357686953459 0, -55.711524110584 -13.3580807761113 0, -55.71730886861859 -13.3591710955438 0, -55.7198276533255 -13.327129129925 0, -55.7005254871978 -13.3255356572483 0))
# getRegionHistory 1
# INFO:sentinelloader:Couldn't get data for 2019-12-22 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2019-12-27 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-01 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-06 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-11 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-16 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-21 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-26 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-31 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-05 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-10 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-15 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-20 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-25 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:showing 0 images
# INFO:sentinelloader:> [started] generating image patches. rows=1; cols=10...
# INFO:sentinelloader:> [done]    generating image patches. rows=1; cols=10 (5.841 ms)
# INFO:sentinelloader:Getting region history for band SCL from 2019-12-22 to 2020-02-27 at 60m
# INFO:sentinelloader:Couldn't get data for 2019-12-22 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# getRegionHistory 2
# INFO:sentinelloader:Couldn't get data for 2019-12-27 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-01 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-06 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-11 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-16 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-21 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-26 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-31 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-05 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-10 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-15 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-20 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-25 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:showing 0 images
# INFO:sentinelloader:> [started] generating image patches. rows=1; cols=10...
# INFO:sentinelloader:> [done]    generating image patches. rows=1; cols=10 (3.932 ms)
# INFO:sentinelloader:Getting region history for band NDVI from 2019-12-22 to 2020-02-27 at 60m
# INFO:sentinelloader:Couldn't get data for 2019-12-22 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2019-12-27 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-01 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-06 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-11 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-16 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-21 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-26 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-01-31 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-05 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-10 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-15 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-20 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:Couldn't get data for 2020-02-25 using the specified filter. err=HTTP status 401 Unauthorized:
# # HTTP Status 401 – Unauthorized
#
# * * *
#
#  **Type** Status Report
#
#  **Message** Unauthorized
#
#  **Description** The request has not been applied because it lacks valid
# authentication credentials for the target resource.
#
# * * *
#
# ### Apache Tomcat/8.0.53
# INFO:sentinelloader:showing 0 images
# INFO:sentinelloader:> [started] generating image patches. rows=1; cols=10...
# INFO:sentinelloader:> [done]    generating image patches. rows=1; cols=10 (5.556 ms)
